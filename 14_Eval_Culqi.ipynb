# %% [markdown]
# <a href="https://colab.research.google.com/github/Gerfer02/Python_2023/blob/main/14_Eval_Culqi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EDA APLICADO A CULQI

# %%
#Cargamos nuestra data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

culqi_df = pd.read_excel("/content/drive/MyDrive/1 Bootcamp_Python_DRSP/6_SextaClase/Ejercicio 2_.xlsx")

culqi_df.head(3)

cdf = culqi_df.dropna()

# %%
cdf.shape
# Out:
# (5034, 11)

# %%
cdf.head(4)
# Out:
#       FECHA VENTA CANAL VENTA  RUC CLIENTE         VENDEDOR  VENTA ACTIVA  \
# 13920  2022-01-17     DEALERS     GJFGCACJ  OMAR BUSTAMANTE             1
# 13921  2022-02-16     DEALERS     DHAGICHD    MARCO CHANAME             1
# 13922  2022-02-17     DEALERS     GEDBJJBA     RUTH PEREYRA             1
# 13924  2022-03-22      BANCOS  BJFJCFHGJFA    JORGE SALAZAR             1
#
#       FECHA ACTIVACION  FLUJO MES VENTA GIRO ECONOMICO DEPARTAMENTO  \
# 13920       2022-01-25            100.0       SERVICIO         LIMA
# 13921       2022-02-25            100.0       COMERCIO         LIMA
# 13922       2022-02-27            100.0     TRANSPORTE         LIMA
# 13924       2022-03-29            100.0   RESTAURANTES       CALLAO
#
#       TIPO PRODUCTO   PRODUCTO
# 13920       OFFLINE  CULQI PRO
# 13921       OFFLINE  CULQI PRO
# 13922       OFFLINE  CULQI PRO
# 13924       OFFLINE  CULQI PRO

# %% [markdown]
# Distribución de Variables:
#
# *  ¿Cuáles son los canales de venta más comunes?
# *  ¿Qué productos se venden más?
# *  ¿Cómo se distribuyen las ventas entre los diferentes departamentos?
# *  ¿Hay algún vendedor específico que tenga un rendimiento notablemente alto o bajo?

# %%
#¿Cuales son los canale de venta más comunes?

canales=culqi_df['CANAL VENTA'].value_counts()
print("canales de ventas comunes:")
print(canales)
# Out:
# canales de ventas comunes:
# DEALERS          11986
# BANCOS            5851
# TELEMARKETING     2405
# ORGANICO          2204
# Name: CANAL VENTA, dtype: int64

# %%
sns.catplot(
    data=cdf,
    x='CANAL VENTA',
    kind='count'
)
plt.show()

# %%
#CUAL ES LA DISTRIBUCION DEL PRODUCTO Y DEL GIRO ECONOMICO
canales=culqi_df['PRODUCTO'].value_counts()
print("Producto mas vendidos:")
print(canales)

sns.catplot(
    data=cdf,
    x='PRODUCTO',
    kind='count'
)
plt.xticks(rotation=75)
plt.show()
# Out:
# Producto mas vendidos:
# CULQI FULL      11926
# CULQI PRO        3770
# CULQI LINK       3143
# CULQI MINI       1636
# SUPER POS        1209
# CULQI ONLINE      760
# CULQI SHOP          2
# Name: PRODUCTO, dtype: int64

# %%
canales=culqi_df['GIRO ECONOMICO'].value_counts()
print("Giros más utilizados:")
print(canales)

sns.catplot(
    data=cdf,
    x='GIRO ECONOMICO',
    kind='count'
)
plt.xticks(rotation=75)
plt.show()
# Out:
# Giros más utilizados:
# COMERCIO              9032
# SERVICIO              4541
# TRANSPORTE            2286
# RESTAURANTES          2204
# TELECOMUNICACIONES    2196
# OTROS                 2187
# Name: GIRO ECONOMICO, dtype: int64

# %%
cdf['PRODUCTO'].value_counts()
# Out:
# CULQI FULL      3690
# CULQI PRO        654
# CULQI MINI       250
# SUPER POS        221
# CULQI LINK       172
# CULQI ONLINE      47
# Name: PRODUCTO, dtype: int64

# %%
#¿Que productos se venden más?

plt.figure(figsize=(10,20)),
sns.catplot(
    data=cdf,
    x='PRODUCTO',
    kind='count'
)
plt.show()

# %%
#¿Cómo se distribuyen las ventas entre los diferentes departamentos?
Ventas_Departamento=cdf.groupby('DEPARTAMENTO')['VENTA ACTIVA'].sum()
print(Ventas_Departamento)
# Out:
# DEPARTAMENTO
# AMAZONAS               28
# ANCASH                 33
# APURIMAC               13
# AREQUIPA              125
# AYACUCHO               36
# CAJAMARCA              51
# CALLAO                104
# CUSCO                 128
# DIOS                    1
# HUANCAVELICA            8
# HUANUCO                98
# ICA                   314
# JUNIN                 325
# LA LIBERTAD           342
# LAMBAYEQUE            205
# LIBERTAD               50
# LIMA                 2766
# LORETO                110
# MADRE DE DIOS           7
# MARTIN                  1
# MOQUEGUA               16
# PASCO                  23
# PIURA                  77
# PROVINCIA DE LIMA       7
# PUNO                    8
# SAN MARTIN             88
# TACNA                  23
# TUMBES                  3
# UCAYALI                44
# Name: VENTA ACTIVA, dtype: int64

# %%
Ventas_Departamento.plot(kind='bar', figsize=(10, 6))
plt.title('Distribución de ventas por departamento')
plt.xlabel('DEPARTAMENTO')
plt.ylabel('VENTAS')
plt.show()

# %%
#AHORA CUAL ES LA VENTA POR PRODUCTO
Ventas_Producto=cdf.groupby('PRODUCTO')['VENTA ACTIVA'].sum()
print(Ventas_Departamento)

#CUANDO QUIERO QUITAR UNA CATEGORIA

Ventas_Producto = Ventas_Producto.drop('CULQI FULL')

print(Ventas_Producto)
# Out:
# PRODUCTO
# CULQI FULL      3690
# CULQI LINK       172
# CULQI MINI       250
# CULQI ONLINE      47
# CULQI PRO        654
# SUPER POS        221
# Name: VENTA ACTIVA, dtype: int64
# PRODUCTO
# CULQI LINK      172
# CULQI MINI      250
# CULQI ONLINE     47
# CULQI PRO       654
# SUPER POS       221
# Name: VENTA ACTIVA, dtype: int64

# %%
Ventas_Producto.plot(kind='bar', figsize=(10, 6))
plt.title('Venta por producto')
plt.xlabel('PRODUCTO')
plt.ylabel('VENTAS')
plt.show()

# %%
#PRODUCTO FILTRADO

Ventas_Producto_Filtrado = Ventas_Producto[Ventas_Producto.index !='CULQI PRO']

print(Ventas_Producto)
# Out:
# PRODUCTO
# CULQI LINK      172
# CULQI MINI      250
# CULQI ONLINE     47
# CULQI PRO       654
# SUPER POS       221
# Name: VENTA ACTIVA, dtype: int64

# %%
Ventas_Producto_Filtrado.plot(kind='bar', figsize=(10, 6))
plt.title('Venta por producto')
plt.xlabel('PRODUCTO')
plt.ylabel('VENTAS')
plt.show()

# %%
#¿Hay algún vendedor específico que tenga un rendimiento notablemente alto o bajo?

# Calcular el total de ventas por vendedor
ventas_por_vendedor =culqi_df.groupby('VENDEDOR')['FLUJO MES VENTA'].sum()
ventas_por_vendedor.sort_values(ascending=False)
# Out:
# VENDEDOR
# OMAR BUSTAMANTE      85959.0
# STEPHANIE MORANTE    80700.0
# AUGUSTO HORNA        68711.0
# LUIS LEON            64966.0
# JOHANA ROJAS         61013.0
#                       ...
# MARLON VALENZUELA        0.0
# ENRIQUE SOLIS            0.0
# ERICA ANTICONA           0.0
# ERICK BENDEZU            0.0
# ZULEMA NEYRA             0.0
# Name: FLUJO MES VENTA, Length: 953, dtype: float64

# %% [markdown]
# #VAMOS A FILTRAR ND

# %%
culqi_filtrado=culqi_df[culqi_df['VENDEDOR'] != 'ND ']

culqi_filtrado.head(5)
# Out:
#   FECHA VENTA    CANAL VENTA  RUC CLIENTE           VENDEDOR  VENTA ACTIVA  \
# 0  2022-01-02         BANCOS  BJDCDAEDCCC       JUAN CORNEJO             0
# 2  2022-01-02         BANCOS     DCGGBCAG       ROSAS STUART             0
# 5  2022-01-03         BANCOS  BJEAGDDAGIB       JUAN CORNEJO             0
# 7  2022-01-03  TELEMARKETING  BJFJJDAHHCB  GIANCARLO ATACUSI             0
# 8  2022-01-03  TELEMARKETING  BJEFAAADJIJ  GIANCARLO ATACUSI             0
#
#   FECHA ACTIVACION  FLUJO MES VENTA      GIRO ECONOMICO DEPARTAMENTO  \
# 0              NaT              NaN  TELECOMUNICACIONES         LIMA
# 2              NaT              NaN            SERVICIO         LIMA
# 5              NaT              NaN            COMERCIO         LIMA
# 7              NaT              NaN            SERVICIO         LIMA
# 8              NaT              NaN            SERVICIO   LAMBAYEQUE
#
#   TIPO PRODUCTO      PRODUCTO
# 0        ONLINE    CULQI LINK
# 2       OFFLINE     CULQI PRO
# 5        ONLINE    CULQI LINK
# 7        ONLINE  CULQI ONLINE
# 8        ONLINE  CULQI ONLINE

# %%
culqi_df  = culqi_df[culqi_df['VENDEDOR'] != 'ND ']

# %%
culqi_df.head(5)

# %%
# Vendedor con las ventas más altas
vendedor_mas_ventas = ventas_por_vendedor.idxmax()
ventas_mas_altas = ventas_por_vendedor.max()
print('El que más vendio es:', vendedor_mas_ventas)
print('Su mejor venta fue:',ventas_mas_altas)
# Out:
# El que más vendio es: OMAR BUSTAMANTE
# Su mejor venta fue: 85959.0

# %%
# Vendedor con las ventas más bajas
vendedor_menos_ventas = ventas_por_vendedor.idxmin()
ventas_mas_bajas = ventas_por_vendedor.min()
print('El que menos vendio:',vendedor_menos_ventas)
print('Su peor venta:',ventas_mas_bajas)
# Out:
# El que menos vendio: ADA NUÑEZ
# Su peor venta: 0.0

# %% [markdown]
# Análisis Temporal:
#
# * ¿Hay alguna tendencia observable en las ventas a lo largo del tiempo?
# * ¿Existen patrones estacionales o eventos específicos que afecten las ventas?

# %%
#¿Hay alguna tendencia observable en las ventas a lo largo del tiempo?
plt.figure(figsize=(15,10))
ventas_diarias = cdf.groupby('FECHA VENTA').size()
ventas_diarias.plot()
# Out:
# <Axes: xlabel='FECHA VENTA'>

# %%
#¿Existen patrones estacionales o eventos específicos que afecten las ventas?
#Si existen patron estacional en el ultimo trimestre del año.
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5034 entries, 13920 to 19345
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FECHA VENTA       5034 non-null   datetime64[ns]
#  1   CANAL VENTA       5034 non-null   object
#  2   RUC CLIENTE       5034 non-null   object
#  3   VENDEDOR          5034 non-null   object
#  4   VENTA ACTIVA      5034 non-null   int64
#  5   FECHA ACTIVACION  5034 non-null   datetime64[ns]
#  6   FLUJO MES VENTA   5034 non-null   float64
#  7   GIRO ECONOMICO    5034 non-null   object
#  8   DEPARTAMENTO      5034 non-null   object
#  9   TIPO PRODUCTO     5034 non-null   object
#  10  PRODUCTO          5034 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(7)
# memory usage: 471.9+ KB

# %% [markdown]
# Relaciones:
#
# * ¿Hay alguna relación entre el canal de venta y el tipo de producto?
# * ¿Los diferentes giros económicos prefieren ciertos productos o canales sobre otros?

# %%
#¿Hay alguna relación entre el canal de venta y el tipo de producto?

cdf  = cdf[cdf['VENDEDOR'] != 'ND ']

cdf  = cdf[cdf['PRODUCTO'] != 'CULQI FULL']
cdf  = cdf[cdf['PRODUCTO'] != 'CULQI PRO']

tab = pd.crosstab(cdf['GIRO ECONOMICO'],cdf['PRODUCTO'])

sns.heatmap(tab)
plt.show()

# %%
cdf  = cdf[cdf['VENDEDOR'] != 'ND ']

cdf  = cdf[cdf['PRODUCTO'] != 'CULQI FULL']
cdf  = cdf[cdf['PRODUCTO'] != 'CULQI PRO']
cdf  = cdf[cdf['DEPARTAMENTO'] != 'LIMA']

tab = pd.crosstab(cdf['PRODUCTO'],cdf['DEPARTAMENTO'])

sns.heatmap(tab)
plt.show()

# %%
#¿Los diferentes giros económicos prefieren ciertos productos o canales sobre otros?
tab = pd.crosstab(cdf['GIRO ECONOMICO'],cdf['PRODUCTO'])

sns.heatmap(tab)
plt.show()

# %%
tab = pd.crosstab(cdf['GIRO ECONOMICO'],cdf['CANAL VENTA'])

sns.heatmap(tab)
plt.show()

# %% [markdown]
# Análisis de Clientes:
#
# * ¿Cuántos clientes únicos hay en el dataset (basándonos en 'RUC CLIENTE')?
# * ¿Hay clientes que compren repetidamente o que tengan un alto volumen de compras?

# %%
cdf.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247 entries, 13936 to 19340
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FECHA VENTA       247 non-null    datetime64[ns]
#  1   CANAL VENTA       247 non-null    object
#  2   RUC CLIENTE       247 non-null    object
#  3   VENDEDOR          247 non-null    object
#  4   VENTA ACTIVA      247 non-null    int64
#  5   FECHA ACTIVACION  247 non-null    datetime64[ns]
#  6   FLUJO MES VENTA   247 non-null    float64
#  7   GIRO ECONOMICO    247 non-null    object
#  8   DEPARTAMENTO      247 non-null    object
#  9   TIPO PRODUCTO     247 non-null    object
#  10  PRODUCTO          247 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(7)
# memory usage: 23.2+ KB

# %%
#¿Cuántos clientes únicos hay en el dataset (basándonos en 'RUC CLIENTE')?
clientes_unicos = culqi_df['RUC CLIENTE'].nunique()

clientes_unicos
# Out:
# 14641

# %%
clientes_unicos = cdf['RUC CLIENTE'].unique()

print(clientes_unicos)

# %%
#¿Hay clientes que compren repetidamente o que tengan un alto volumen de compras?
df = culqi_df['RUC CLIENTE'].value_counts()

Top_5 = df.head(5)

print(Top_5)
# Out:
# BJFJHHCHEDG    120
# BJFJBJEIBFA     75
# BJFJICJFFFB     45
# BJFJDCCIDDI     34
# BJECCIFFHBJ     26
# Name: RUC CLIENTE, dtype: int64
